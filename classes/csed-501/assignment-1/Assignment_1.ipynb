# %% [markdown]
# #Assignment 1: Regression
#
# In this assignment, you will:
#
#
# *   Use ```Pandas``` to load and inspect data
# *   Use tools from ```sklearn``` to pre-process data for training and testing
# *   Use tools from ```sklearn``` to train multiple regression algorithms and optimize performance
# *   Compare the performance of these algorithms
# *   Add text cells with writeup with your answers (indicated throughout the assignment)

# %% [markdown]
# **If you used AI to complete this assignment, edit this text box to include the tool used.**
#
# I used the following AI tool to complete this assignment (leave blank if none):
#
# Additional questions: were there any mistakes that the AI made that you had to correct? If so, list one example.

# %% [markdown]
# #Pandas for loading and inspecting data
#
# In this assignment, we will introduce ```Pandas```, a library for working with data in the form of ```Dataframes```. We will cover some of the uses of ```Pandas``` throughout this and future assignments, but will not cover every possible usage. [```Pandas``` documentation](https://pandas.pydata.org/docs/user_guide/10min.html) is available.
#
# For this assignment, we will use a [dataset of house sales in King County, WA](https://www.kaggle.com/datasets/harlfoxem/housesalesprediction). This data is from May 2014-May 2015, so housing prices may be lower than expected in today's market, but the same principles for training different regression models apply.
#
# 1. **Loading and inspecting data** (10 pts)
#
# 1(a) (3 pts). First, load in the data (```kc_house_data.csv```) to a variable called ```housing``` using [```Pandas read_csv```](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html). The only argument you should need to provide is the filename of the dataset as a string. Then, remove the columns ```"id"``` and ```"date"``` using the [Pandas drop()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html) function

# %%
import pandas as pd
import numpy as np

#TODO: Your code here
housing = None

# %% [markdown]
# 1(b). (2 pts) Now that the data is loaded, look at the first few lines of the dataset using the [```pandas``` head function](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html).

# %%
#TODO: Your code here

# %% [markdown]
# 1(c) (4 pts). Next, use the [```pandas``` describe function](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html#pandas.DataFrame.describe) to show description statistics about the dataset. **In the following text cell, report the mean and standard deviation of the ```price```, ```bedrooms```, ```bathrooms```, and ```sqft_living``` with units, rounded to 2 decimal places (the ```price``` numbers can be left in e notation if desired).** See the [dataset of house sales in King County, WA](https://www.kaggle.com/datasets/harlfoxem/housesalesprediction) for units.

# %%
#TODO: Your code here

# %% [markdown]
# **Reported means/standard deviations**
#
# Your answers here

# %% [markdown]
# 2. **Setting up data for training** (20 pts)
#
# You now need to get the ```housing``` DataFrame ready for ```sklearn``` machine learning training and testing.
#
# 2a (2 pts). First, for ease of training and testing, you should separate the target variable ('price') from the features (all other columns). Use the [Pandas drop()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html) function to save all features in a variable called ```X```. Save the target variable in a variable called ```y```.

# %%
# Separate the target value (price) and the features
#TODO
X = None
y = None

# %% [markdown]
# 2b (2 pts). Next, this dataset has many features. To simplify the training process for the first part of this assignment, you should only use the ```bedrooms```, ```bathrooms```, ```sqft_living```, and ```sqft_basement``` features. Create a DataFrame called ```X_basic``` that only contains these features. (Hint: you can create a list of the feature labels you want, and use this list to [index](https://pandas.pydata.org/docs/user_guide/indexing.html) into the ```housing``` DataFrame)

# %%
#Choose features
#TODO
X_basic = None

# %% [markdown]
# 2c (2 pts). Now you'll need a training and testing set. Using [train_test_split()](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) from sklearn, create training sets called ```X_train_basic``` ('basic' indicating that this contains only the basic variables chosen above) and ```y_train``` and testing sets called ```X_test_basic``` and ```y_test```. The training set should contain 80% of the data, and the testing set should contain 20% of the data. Pass in ```random_state=42```; by default, ```train_test_split()``` shuffles the data into a random order before splitting to make sets more representative of all of the data.

# %%
from sklearn.model_selection import train_test_split
#Split data into training and testing sets
#TODO
X_train_basic, X_test_basic, y_train, y_test = None

# %% [markdown]
# 2d (10 pts). Let's visually examine the data. [Seaborn](https://seaborn.pydata.org/) is a plotting library that can create clean and visually appealing plots from DataFrames and arrays and can be used to improve plot access (for example, by using [color palettes](https://seaborn.pydata.org/tutorial/color_palettes.html) designed for colorblindness). Seaborn pairplots are one way to plot comparisons between features (and target values) and see how they correlate. Use the [pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html) function to plot the ```housing``` dataset; you'll want to set the ```y_vars``` and ```x_vars``` parameters appropriately so that you end up with four plots: each will generate a pairwise relationship plot of a basic variable vs the target value.
#
# Next, Pandas can help you find the correlations between each of the basic features and the price. Using [```corr()```](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html), calculate the correlation values of the ```price``` and all basic features. **In the text cell below the code, report the name and correlation value rounded to two decimal places of the highest correlated feature.** Note: we're not looking for the diagonal entries or the correlation between features themselves; you should report a single number for each basic feature, the correlation between itself and ```price```.

# %%
import seaborn as sns

#Plot pairwise relationships
#TODO

#Calculate correlations
#TODO

# %% [markdown]
# **Reported feature with highest correlation with price, with correlation value**
#
# Your answer here

# %% [markdown]
#  2e (4 pts). Models like SGDRegressor, Ridge, and LASSO assume that the input features are standardized and that the target values are centered (have a mean of 0). In this assignment, you'll use [StandardScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html) to standardize the data in your training and testing sets (features only, not the target value). First, ```fit``` an instance of ```StandardScaler()``` to the data (this enables StandardScaler to find the mean and standard deviation of each features. You'll then apply the ```transform``` function to your training and testing sets, saving the standardized data in the variables ```X_train_basic_standardized``` and ```X_test_basic_standardized```.
#
#  Remember from class: the ```fit``` function should only be run on the training set, because you want your statistics/transformations to be consistent across all of your data, and in the real world you cannot train using statistics from all potential future data. You'll apply the transformation to both the training and testing sets.

# %%
from sklearn.preprocessing import StandardScaler
#Standardize data
#TODO
X_train_basic_standardized = None
X_test_basic_standardized = None

# %% [markdown]
# 3. **Training and testing linear regression** (30 pts)
#
# 3a (24 pts). Now, let's train and test some basic linear regression models. You'll use ```LinearRegression``` and ```SGDRegressor``` from ```sklearn```. Train both LinearRegression and SGDRegressor (with default parameters) on your ```X_train_standardized``` features, then use the ```predict()``` function to predict the labels on ```X_test_standardized```. **Calculate the [RMSE](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.root_mean_squared_error.html) and [$R^2$ score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html) for both models on the test set and report them in the text cell below rounded to two decimal places and report which model performed better.**
#
# For the rest of the assignment, when training your regression models that use randomness (```SGDRegressor``` when ```shuffle=true```, the default parameter setting that shuffles the training data after each epoch), pass the parameter ```random_state=42``` to the model. This will cause the random shuffle to be performed the same every time, which is helpful for comparing models, and in this course, helps us ensure that your answers are correct as we can compare to the sample solution output. When deploying in the real world, you should not set ```random_state```, but it can be useful for development.

# %%
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.metrics import root_mean_squared_error

# Train Linear Regression model
#TODO

# Predict on the test set
#TODO

# Calculate RMSE
#TODO

# Calculate R^2
#TODO

# Train SGD Regressor model
#TODO

# Predict on the test set
#TODO

# Calculate MSE
#TODO

# Calculate R^2
#TODO

# %% [markdown]
# **Reported RMSE and $R^2$ for ```LinearRegression()``` and ```SGDRegressor()```**
#
# Your answers here
#
# **Which model performed better on the test set?**
# Your answer here

# %% [markdown]
# 3b (6 pts). If you were a real estate agent with access to this model and a customer came to you with a house with 1 bedroom, 2 bathrooms, sq footage of 1000 sq ft, and a basement sq footage of 200 sq ft, what price would you predict their house might sell for using the best model from above? See [Pandas DataFrames](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html) for a reference on creating a DataFrame for testing.

# %%
#TODO

# %% [markdown]
# **What price would you predict their house would sell for?**
#
# Your answer here

# %% [markdown]
# 4. (40 pts) **Training and testing regularized regression**
#
# Now, let's train and test Ridge and LASSO. We'll use [```Ridge()```](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html) and [l```Lasso()```](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html) for our sklearn models.
#
# 4a (4 pts). First, because Ridge and LASSO use regularization, we can easily use more features. Create a new train and test set, ```X_train_all``` (80%) and ```X_test_all``` (20%). Remember to pass in ```random_state=42```.
#
# Then, using the same method as above, standardize the training and testing sets, saving in variables ```X_train_all_standardized``` and ```X_test_all_standardized```.
#
# Note: after standardization, we'll clip the values to a range of -3,3 to prune some outlier data. Uncomment the lines with np.clip() after creating ```X_train_all_standardized``` and ```X_test_all_standardized```.

# %%
#Split training data with all features into training and testing sets
#TODO
X_train_all, X_test_all, y_train, y_test = None

#Standardize data
#TODO

#UNCOMMENT BELOW LINES WHEN ABOVE CODE COMPLETED
#X_train_all_standardized = np.clip(X_train_all_standardized, -3, 3)
#X_test_all_standardized = np.clip(X_test_all_standardized, -3, 3)

# %% [markdown]
# 4b (20 pts). The setting of the regularization parameter for Ridge and LASSO greatly affects performance, so we'll utilize grid search to find good settings. For this, we'll use [GridSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html).
#
# There are four important parameters that we'll set for GridSearchCV: ```estimator``` (the instance of ```Ridge``` or ```Lasso```), ```param_grid``` (a dictionary with parameters names (str) as keys and lists of parameter settings to try as values), ```cv``` (the cross-validation splitting strategy), and ```scoring``` (the strategy to evaluate the performance of the cross-validated model on the test set). We'll guide you through setting these.
#
# * ```estimator```: use ```Ridge()``` and ```Lasso()``` with the argument ```max_iter``` set to 5000.
# * ```param_grid```: ```sklearn``` calls the regularization parameter ```alpha```. Create a dictionary with the key ```'alpha'``` (a string), and a value consisting of a list of ```alpha``` settings to try. We suggest starting with values ranging from $10^{-3}$ to $10^{3}$ evenly spaced on a log scale ([```np.logspace(-3, 3, 7```)](https://numpy.org/doc/2.0/reference/generated/numpy.logspace.html)) for both LASSO and Ridge, but you can also try your own values to attempt to improve performance.
# * ```cv```: we recommend using ```cv=4``` for 4-fold cross-validation, but you can also try other values (generally in the range 3-10).
# * ```scoring```: since we're measuring performance in RMSE for this assignment, use ```scoring='neg_root_mean_squared_error'```. GridSearchCV is set up to maximize metrics, not minimize, so this uses the negative RMSE value so that maximizing makes sense.
#
# Use GridSearchCV to find good parameters for LASSO and Ridge. You'll first instantiate GridSearchCV (with the parameters suggested above), then ```fit``` the GridSearchCV instantiation to your standardized training set (containing all features) created above. **In the text cell below, report the best ```alpha``` for Ridge and LASSO.** You can use the ```best_params_``` attribute of GridSearchCV to find the best alpha.

# %%
from sklearn.model_selection import GridSearchCV
import numpy as np

#Initialize and fit GridSearchCV for Lasso
#TODO

#Initialize and fit GridSearchCV for Ridge
#TODO

#Find best alpha parameter for LASSO and Ridge
#TODO

# %% [markdown]
# **Reported best alpha for LASSO (l1) and Ridge (l2) regression**
#
# Your answers here

# %% [markdown]
# 4c (16 pts). Using the best ```alpha``` parameters found above, train and test a Ridge and LASSO model. **Find each of their RMSEs and $R^2$ scores and report in the text cell below.** And as always, set ```random_state=42``` for consistency.

# %%
import numpy as np
from sklearn.linear_model import SGDRegressor

# Train Lasso with best parameters
#TODO

# Find RMSE on LASSO test set
#TODO

# Train Ridge with best parameters
#TODO

# Find RMSE on Ridge test set
#TODO

# %% [markdown]
# **Reported RMSE and $R^2$ for LASSO (l1) and Ridge (l2) regression to 2 decimal places**
#
# Your answers here
