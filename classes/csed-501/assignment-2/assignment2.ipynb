# %% [markdown]
# #Assignment 2: Classification
#
# In this assignment, you will:
#
#
# *   Use ```Pandas``` to load and inspect data
# *   Use tools from ```sklearn``` to pre-process data for training and testing
# *   Use tools from ```sklearn``` to train multiple classification algorithms and optimize performance
# *   Compare the performance of these algorithms
# *   Add text cells with writeup with your answers (indicated throughout the assignment)

# %% [markdown]
# **If you used AI to complete this assignment, edit this text box to include the tool used.**
#
# I used the following AI tool to complete this assignment (leave blank if none):
#
# Additional questions: were there any mistakes that the AI made that you had to correct? If so, list one example.

# %% [markdown]
# #Load, Pre-process, and Inspect Data
#
# For this assignment, we will use a [dataset of banking customers](https://www.kaggle.com/datasets/shubhammeshram579/bank-customer-churn-prediction) to predict "churn" (when customers stop doing business with the bank). Companies can use churn data to predict whether or not new customers are likely to stop doing business with them, or analyze factors that suggest a customer may churn. Companies can use this information to attempt to reduce customer churn rates over time.
#
# We will be using classification algorithms to use customer data to predict whether that customer will churn or not.
#
#
# 1. **Loading and analyzing data** (15 points)
#
# 1(a) (1 points). First, load in the data (```Churn_Modelling.csv```) to a variable called ```churn```. Then, remove the columns ```"RowNumber"```, ```"CustomerId"```, and ```"Surname"```.(features unecessary to learning for this particular setup). Once the data is loaded, look at the first few lines of the dataset.

# %%
import pandas as pd
import numpy as np

churn = ... # TODO

# Display first entries in the dataset
# TODO

# %% [markdown]
# 1(b) (4 points). Next, we'll handle some rudimentary data cleaning. First, use [```dropna()```](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html) to remove any rows with missing data (there are a few in this dataset).
#
# Next, we'll handle categorical features using one-hot encoding. The [```get_dummies```](https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html) function can easily create one-hot encodings for the categorical features. Use the ```drop_first``` parameter to create $C-1$ one-hot features instead of $C$, where $C$ is the number of categories included in the features. This $C$ will depend on the data you have; for example, ```"Gender"``` in this dataset only has two values, so you should use a one-hot encoding in a single feature; this could change based on how individual datasets record gender. Use this function with the selected ```columns```, then look at the first few entries of the dataset again.

# %%
# Remove rows with missing data
# TODO

# Handle categorical features using one-hot encoding
# TODO

# %% [markdown]
# **Question:** In this text box, provide the new variable names that replaced ```"Geography"``` and ```"Gender"```.
#
# **Answer:** TODO

# %% [markdown]
# 1(c) (2 points). Separate the target variable (```"Exited"```) from the features (all other columns). Save the features in a variable ```X```, and the target variable in a variable ```y```. Split into training (70%), validation (15%), and testing (15%) sets; to get three sets using [```train_test_split()```](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html), you can first split into two sets (70%, 30%), and then use ```train_test_split()``` again to split the 30% set in half for validation and testing. Remember to use ```random_state=42```.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Separate features and target variable
X = ... # TODO
y = ... # TODO

# Split into training and the rest (validation + test)
X_train, X_rest, y_train, y_rest = ...  # TODO

# Split the rest into validation and testing
X_validation, X_test, y_validation, y_test = ... # TODO

# %% [markdown]
# 1(d) (8 points). Count the number of ```Exited=0``` and ```Exited=1``` in the training set. Plot the counts using a barplot [(seaborn barplot)](https://seaborn.pydata.org/generated/seaborn.barplot.html). Seaborn barplots can be modified to have specific titles, x and y axis labels, and more using matplotlib. We've imported both libraries for you; a [quick introduction to matplotlib](https://matplotlib.org/stable/tutorials/pyplot.html#sphx-glr-tutorials-pyplot-py) may be helpful to read. Use [```plt.title()```](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.title.html), [```plt.xlabel()```](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlabel.html), and [```plt.ylabel()```](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylabel.html) to set appropriate labels and titles for the barplot graph.

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Count the occurrences of each value in the 'Exited' column
exited_counts = ... # TODO


# Plot the counts using sns.barplot
# TODO

# %% [markdown]
# **Question:** In this text box, discuss what the results mean for your data analysis: would achieving greater than 50% accuracy beat a reasonable baseline classifier?
#
# **Answer:** TODO

# %% [markdown]
# **Question:** What do the above results imply for your classifier accuracy analysis?
#
# **Answer:** TODO

# %% [markdown]
# 2. **Creating a baseline and training a basic classifier** (40 points)
#
# 2(a) (10 points). Based on the results of 1(d), create a reasonable baseline classifier: that is, create a new ```y_validation_baseline``` vector that has the same number of entries as your ```x_validation``` and ```y_validation``` vectors, and assign each entry a constant value. The value(s) you choose should maximize the percentage of correct classifications that can be achieved without any learning or more data analysis than you have already performed on this datset. Calculate the accuracy score of this baseline on the validation set using sklearn's [```accuracy_score```](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html).

# %%
from sklearn.metrics import accuracy_score

# Base line vector
y_validation_baseline = ... # TODO

# Compute the accuracy of the baseline classifier
baseline_accuracy = ... # TODO

print(f"Baseline Classifier Validation Accuracy: {baseline_accuracy}")

# %% [markdown]
# **Question:** Report the accuracy of your baseline classifier in this text box.
#
# **Answer**: TODO

# %% [markdown]
# 2(b) (10 points). Now you'll train two Logistic Regression models without regularization (set argument ```penalty=None``` in [```LogisticRegression```](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html)). Standardize the data before training; while this is not required for logistic regression, it can improve performance.
#
# One logistic regression model should have no class weights (argument ```class_weight=None```). The other should be applying class weights to inversely proportional to class frequencies in the input data (argument ```class_weight='balanced'```). Evaluate the accuracy of both models using ```accuracy_score``` on the validation set.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# Standardize the features
# TODO

# Train two logistic regression models (both with no regularization, one with balanced class weights)
# TODO

# Predict on the validation set with unbalanced logistic regression
y_validation_pred_unbalanced = ... # TODO
# Predict on the validation set with balanced logistic regression
y_validation_pred_balanced = ... # TODO

# Evaluate the models
accuracy_unbalanced = ... # TODO
accuracy_balanced = ... # TODO

print(f"Validation Accuracy of unbalanced logistic regression: {accuracy_unbalanced}")
print(f"Validation Accuracy of balanced logistic regression: {accuracy_balanced}")

# %% [markdown]
# **Question:** Report the accuracy of the Logistic Regression classifiers in this text box rounding to three (3) decimal places.
#
# **Answer**:
#   - Accuracy of the unbalanced Logistic Regression classifier: TODO
#   - Accuracy of the balanced Logistic Regression classifier: TODO

# %% [markdown]
# **Question:** Compare the relative improvement to your previously created baseline; are the results what you expect? Why or why not?
#
# **Answer:** TODO

# %% [markdown]
# 2(c) (15 points). Now calculate the confusion matrices of both models (balanced and unbalanced) and your baseline model using [```confusion_matrix```](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html). Save the unbalanced confusion matrix in a variable ```cm_unbalanced```, the balanced confusion matrix in a variable ```cm_balanced```, and the baseline confusion matrix in a variable ```cm_baseline```, and the code block below your entry will print out a nicely-generated heatmap.

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm_unbalanced = ... # TODO
cm_balanced = ... # TODO
cm_baseline = ... # TODO

# Print the confusion matrix
print("Unbalanced Confusion Matrix:")
print(cm_unbalanced)
print("Balanced Confusion Matrix:")
print(cm_balanced)
print("Baseline Confusion Matrix:")
print(cm_baseline)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm_unbalanced, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Exited', 'Exited'], yticklabels=['Not Exited', 'Exited'])
plt.title('Unbalanced Confusion Matrix Heatmap')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

plt.figure(figsize=(8, 6))
sns.heatmap(cm_balanced, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Exited', 'Exited'], yticklabels=['Not Exited', 'Exited'])
plt.title('Balanced Confusion Matrix Heatmap')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

plt.figure(figsize=(8, 6))
sns.heatmap(cm_baseline, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Exited', 'Exited'], yticklabels=['Not Exited', 'Exited'])
plt.title('Baseline Confusion Matrix Heatmap')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# Let's call ```Exited=1``` positive and ```Exited=0``` negative.
#
# **Question:** Report true positives, true negatives, false positives, and false negatives for the unbalanced model.
#
# **Answer:**
#   - True positives: TODO
#   - True negatives: TODO
#   - False positives: TODO
#   - False negatives: TODO

# %% [markdown]
# **Question:** Report true positives, true negatives, false positives, and false negatives for the balanced model.
#
# **Answer**:
#   - True positives: TODO
#   - True negatives: TODO
#   - False positives: TODO
#   - False negatives: TODO

# %% [markdown]
# **Question:** Report true positives, true negatives, false positives, and false negatives for the baseline.
#
# Answer:
#   - True positives: TODO
#   - True negatives: TODO
#   - False positives: TODO
#   - False negatives: TODO

# %% [markdown]
# **Question:** Discuss for this problem whether you believe false positives or false negatives are more detrimental, and whether that affects which model you might choose to deploy.
#
# **Answer:** TODO

# %% [markdown]
# **Question:** Compare the number of false positives and false negatives of the balanced and unbalanced models to your previously created baseline; are the results what you expect? Why or why not?
#
# **Answer:** TODO

# %% [markdown]
# 2(d) (5 points). The learned coefficients are stored in the .coef_ attribute of the Logistic Regression model as an array of shape (1, n_features); you can get an array of the coefficients by calling ```logistic_regression_model.coef_[0]```. Find the highest and lowest absolute value of coefficients of the unbalanced model and report which feature they belong to (```.coef_[0]``` will give coefficients for features in the same order as the columns of your training set). Report the highest and lowest coefficient/features of the unbalanced model in the text box below.

# %%
# Get the abs value coefficients from the trained logistic regression model
coefficients = ... # TODO

# Find the feature with the highest coefficient
highest_coef_name = ... # TODO
highest_coef_value = ... # TODO

# Find the feature with the lowest coefficient
lowest_coef_name = ... # TODO
lowest_coef_value = ... # TODO

print(f"Feature with the highest coefficient: {highest_coef_name} ({highest_coef_value})")
print(f"Feature with the lowest coefficient: {lowest_coef_name} ({lowest_coef_value})")

# %% [markdown]
# **Question**: Report the highest and lowest absolute-valued coefficients(rounding to three (3) decimal places) and the corresponding feature names
#
# **Answer**:
# - Highest coefficient name and value: TODO
# - Lowest coefficient name and value: TODO

# %% [markdown]
# 3. **Decision Trees** (20 points)
#
#
# 3(a) (10 points). Now, let's train a decision tree instead of logistic regression. You'll use sklearn's [```DecisionTreeClassifier```](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html) for this model. Use ```random_state=42``` in your ```DecisionTreeClassifier```.
#
# Using your training and validation sets (**not** ```GridSearchCV```), choose a setting of ```max_depth``` (the maximum depth that the tree will grow to) between 1 and 10. Choose based on the accuracy score performance using the ```scoring``` parameter: for a list of scoring methods that can be used, see the [sklearn documentation for scoring](https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-string-names). Report the depth of tree you choose and the accuracy score that it achieved in the text box below.

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# Manual Cross Validation. DO NOT USE GridSearchCV!!!
# TODO

# %% [markdown]
# **Question**: Report the best max depth setting and accuracy to three (3) decimal places:
#
# **Answer:** depth=TODO, accuracy=TODO

# %% [markdown]
# 3(b) (10 points). Train a model with your chosen max depth setting and save it in ```decision_tree_model```. Compute the confusion matrix on the validation set and report the values in the text box below. Save the confusion matrix in ```cm_tree```. The second code cell will show a heat map of the matrix, and the third code cell will show a visualization of the learned decision tree.

# %%
decision_tree_model = ... # TODO
cm_tree = ... # TODO
print(cm_tree)

# %%
"""
This code will provide a heatmap of the confusion matrix.
"""
import seaborn as sns
import matplotlib.pyplot as plt

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm_tree, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Exited', 'Exited'], yticklabels=['Not Exited', 'Exited'])
plt.title('Decision Tree Confusion Matrix Heatmap')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# **Question:** Report true positives, true negatives, false positives, and false negatives for the tree model.
#
# **Answer:**
#   - True positives: TODO
#   - True negatives: TODO
#   - False positives: TODO
#   - False negatives: TODO

# %%
"""
This code will provide a visualization of the decision tree.
"""

import graphviz

tree_data = tree.export_graphviz(decision_tree_model, out_file=None, feature_names=X_train.columns, class_names=['Not Exited', 'Exited'], filled=True, rounded=True, special_characters=True, impurity=False)
graph = graphviz.Source(tree_data)
display(graph)

# %% [markdown]
# **Question**: Based on the visualized decision tree, what are the top three most important features for classifying our churn data?
#
# Answer: TODO

# %% [markdown]
# 4. **Random Forests** (25 points)
#
#
# 4(a) (12 points). Now, let's train random forests instead of a single decision tree. You'll use sklearn's [```RandomForestClassifier```](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html) for this model. Use ```random_state=42``` in your ```RandomForestClassifier```.
#
# Using your training set, use [GridSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html) with argument ```cv=5``` to choose settings for the number of decision trees used in the model (try 100, 200, and 300), the maximum depth that each tree can grow to (try 5-10, inclusive), and the maximum number of features to be used to inform each decision tree (try 3-5, inclusive). To find what arguments to pass to ```GridSearchCV```, read the provided documentation and find the parameter options that match these hyperparameters. Choose settings based on the accuracy score performance. Report the best setting of each value in the text box below along with the best accuracy achieved. Note: this code may take 5-10 minutes to run.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import pandas as pd

# Find the best parameters using GridSearchCV
# TODO

# Get the best parameter setting and the validation accuracy corresponding to it
best_params = ... # TODO
best_accuracy = ... # TODO

# Print the best parameters and best score
print(f"Best parameters: {best_params}")
print(f"Best cross-validation accuracy: {best_score}")

# %% [markdown]
# **Question**: Report the best hyperparameter settings and accuracy to three (3) decimal places for that setting.
#
# **Answer**: max_depth=TODO, max_features=TODO, n_estimators=TODO, accuracy=TODO

# %% [markdown]
# 4(b) (5 points). Using the best parameters, train a Random Forest classifier. Use ```random_state=42``` in your ```RandomForestClassifier```. Compute the confusion matrix on the validation set. Save the confusion matrix in ```cm_forest```. The second code cell will show a heat map of the matrix.

# %%
rf_model = ... # TODO
cm_forest = ... # TODO
print(cm_forest)

# %%
"""
This code will provide a heatmap of the confusion matrix.
"""
import seaborn as sns
import matplotlib.pyplot as plt

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm_forest, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Exited', 'Exited'], yticklabels=['Not Exited', 'Exited'])
plt.title('Random Forest Confusion Matrix Heatmap')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# **Question:** Report true positives, true negatives, false positives, and false negatives for the random forest model.
#
# **Answer:**
#   - True positives: TODO
#   - True negatives: TODO
#   - False positives: TODO
#   - False negatives: TODO

# %% [markdown]
# 4(c) (8 points). [```HalvingGridSearchCV``` ](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.HalvingGridSearchCV.html#sklearn.model_selection.HalvingGridSearchCV) implements halving grid search in sklearn, and should run faster than ```GridSearchCV```. Use this method to search over the same parameters from 4(a) and report the best setting of each value in the text box below along with the best accuracy achieved. You do not need to use any of the additional parameters provided by ```HalvingGridSearchCV```, but use ```random_state=42```.

# %%
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV


# Find the best parameters using GridSearchCV
# TODO

# Get the best parameter setting and the validation accuracy corresponding to it
best_params = ... # TODO
best_accuracy = ... # TODO

# Print the best parameters and best score
print(f"Best parameters: {best_params}")
print(f"Best cross-validation accuracy: {best_score}")

# %% [markdown]
# **Question**: Report the best hyperparameter settings and accuracy to three (3) decimal places for that setting.
#
# **Answer**: max_depth=TODO, max_features=TODO, n_estimators=TODO, accuracy=TODO

# %% [markdown]
# **Question:** What change(s) might you make during the training and validation process if you wished to, for example, optimize for reduced false negatives rather than increased accuracy?
#
# **Answer:** TODO
