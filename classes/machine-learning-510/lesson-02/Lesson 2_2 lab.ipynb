# %% [markdown]
# ## <h1>Linear Regression</h1>

# %% [markdown]
# <B>Let's generate some data that shows roughly linear relationship between page speed and amount purchased</B>

# %%
# %matplotlib inline
import numpy as np
from pylab import *

pageSpeeds = np.random.normal(3.0, 1.0, 1000)
print(pageSpeeds)
# Out:
# [ 3.18864222  4.51703034  1.83158702  3.59772798  2.28038003  2.98728256
#   2.50964879  2.29342781  2.80915829  3.68689054  3.16576886  0.69902685
#   2.88307541  2.37995835  3.87395416  3.10588665  3.0447321   2.93412535
#   2.60152996  3.5686181   3.59597874  1.64257339  3.88466761  2.39884761
#   3.12126906  1.42492325  1.81078401  3.98824972  3.11593022  4.09880253
#   2.77742511  2.7872432   1.75503414  3.45696227  2.57038762  1.28273661
#   2.2996489   2.38113923  3.23096836  2.64597915  2.68965519  0.7176666
#   3.24136018  4.26483105  3.4355698   2.2529729   2.35187957  2.59221605
#   5.06244691  0.41972601  1.45969864 -0.57141561  2.55852206  4.012169
#   3.81772086  3.88324436  3.45112934  2.93985277  1.96420335  3.98200336
#   1.47531583  2.411837    2.73740138  5.39278269  2.92082967  3.22482235
#   3.77455243  3.66273772  2.23834478  2.42920164  2.73806641  3.58759434
#   2.92385383  1.54152631  2.27567682  2.83436381  2.5969514   2.85536074
# ...

# %%
purchaseAmount = 100 - (pageSpeeds + np.random.normal(0, 0.1, 1000)) * 3

scatter(pageSpeeds, purchaseAmount)

# %% [markdown]
# <b>As we only have two features, we can keep it simple and just use scipy.state.linregress:</b>

# %%
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)

# %%
import matplotlib.pyplot as plt

def predict(x):
    return slope * x + intercept

fitLine = predict(pageSpeeds)

plt.scatter(pageSpeeds, purchaseAmount)
plt.plot(pageSpeeds, fitLine, c='r')
plt.show()

# %% [markdown]
# <b>Not surprisingly, our r-squared value shows a really good fit</b>

# %%
r_value ** 2
# Out:
# 0.9895699826195941
